# %% [markdown]
# # On the Modeling of Shear Stress in a High-Shear Thin-Gap Rotating Disk Grinder for Nano-Cellulose
#
# * Authors: AH, TB and DL
# * Target Journal: journal in numerical simulation field, e.g. App. Math. Comp.
# * Scientific contribution: we quantify how strain and shear stress in the gap depend on operational conditions such as (1/5) rotor rotational speed (what is the range? what is expected from literature), (2/5) inlet pressure (range? expected outcome?) and (3/5) gap size or clearance (range? expected outcome?), (4/5) on the visco-elastic properties of the cellulose material being processed (shear thinning properties) and on design of the mill ((5/5) e.g. the surface roughness of the mill). We emphasize on RANS turbulent flow simulation to gain insight in these factors. We report on experimental values of rotor torque and expected values of shear stress wherever possible;
#
# <b>Nomenclature</b>
# * fibrilation vs. grinding vs., milling: choose one;
# * gap vs. milling zone vs. fibrilation zone: choose one;
#
# <div class="alert alert-block alert-danger"> Ask TB to add references on the mechanical production of nano-cellulose.</div>
#
# <div class="alert alert-block alert-danger"> Does TB wish to disclose geometry dimensions? See slide-7 of Third iteration CFD model TAU TU DELFT Collab v1.pptx</div>
#
# <div class="alert alert-block alert-danger"> Does TB wish to disclose inlet operating conditions?</div>
#
# <div class="alert alert-block alert-danger"> Does TB wish to elaborate on the milling in various stages (function, characteristics, outcome)?</div>
#
# <div class="alert alert-block alert-danger"> How TB wish to compare CFD results with experimental data?</div>

# %% [markdown]
# ### Section 1: Introduction
#
# <b>Motivation and Problem Description</b>: We study the mechanical production of cellulose nano-fibrils from wood pulp using a high shear thin gap rotating disk grinder. Currently, the process is lengthy, requires operator oversight and is energy intensive. See e.g. Ref-1 for more details. (Extend with reference to literature on nano-cellulose materials and its mechanical production). (What can be disclosed on particle size distribution after various stages of the milling process. What can be disclosed on magnitude of the shear stress required to break up the particles.);
#
# <b>Pilot scale lab setup</b>: To study the grinding process, to reduce energy consumption and to seek to automate and to up-scale the grinding process, a pilot-scale set-up was developed at Tampere university. Set-up similar to grinder described in Ref-2. Describe pilot set-up in more details. Flow through grinder is controlled by two factors. The first factor the mass flow rate through the grinder cointrolled by an exterbnal pump. The second factor is the rotational speed of the rotor. Cite previous publication from Tampere. While providing a lot of insight, indispensable insight on the effect of process parameters remains missing.
#
# <b>Previous work on the CFD modeling of high-shear thin-gap rotating disk grinders with throughflow</b>: We seek to develop a mathematical model for the grinding process (requires more precise statement as break-up of solid particles, visco-elastic behavior and heat effects is not yet taking into account). This model is intended to complement the pilot scale set-up with indispensable insights. Discuss previous published work on modeling of turbulent flow between rotating disks with throughflow. See Ref-3, Ref-4, Ref-5 and Ref-6. Let $R_D$, $h$, $\nu$, $\omega$ and $Q$ denote the radius of the rotor, the height of the gap, the kinematic viscosity of the fluid, the angular velocity of the rotor and the flow rate (mass of volume), respectively. Then $Re_{\omega} = \omega \,R_D \, \nu$, $C_w = Q \, \nu^{-1} \, R_D^{-1}$ and $G = h \, R_D^{-1}$ denote the rotational Reynolds number, the dimensionless flow rate and the aspect ratio of the gap, respectively. Flow can be either rotational governed (Bachelor regime or torsional Couette flow), throughflow governed (Stewartson regime) or inbetween. Ekman or von Karman boundary layer (rotor), central core, Bodewalt layer (stator).
#
# The effect of the surface roughness on the line friction coefficient was considered in Ref-6 (required more elaboration. Good to look into Couette flow first). Modeling of surface roughness and boundary layer thickness of rough layers. See Ref-6 in particular.
#
# Rotor-stator systems have studied before in literature but generally have significant differences compared to the micro grinding process. Good to be more explicit on what has been left out in the literature in order to reinforce the scientific contributions in the paper.
#
# <b>Our Contribution - Case Description</b>: Modeling of laboratory set-up. Goal is to complement trial runs with insights from flow modeling. Focus on the quantification of the shear stress in the milling gap.
# * Flow between rotating disks with radial throughflow.
# * generation of large shear force due to merging of the boundary layers:
#
# <b>Outside of Scope</b>: (Explicitly state the boundaries of the model developed in this paper. E.g. <i>In this paper, we assume that the flow is isothermal although thermal efforts have been recognized to be important in this application.</i>;
# * no heat effects, thus no dependence of the molecular viscosity on the temperature using e.g. Sustherland Law and no anomaly in case of insufficient cooling: although simpleFoam could be replaced by rhoSimpleFoam. Both adiabatic (no heat loss to the environment) as well as non-adiabatic (including heat loss to the environment could be developed). Thermal boundary layer. The cooling systems should be taken into account. Two alternatives to account for heat loss to the environment do exist. The first (easier) alternative is to use appropriate boundary conditions. The second (more complex) alternative is to adopt a solid-fluid formulation seperated by an interface;
# * no transient flow behavior and thus no information of Taylor vortex structure, interaction between vortices and interaction between vortices and the wall: although simpleFoam could be replaced by pimpleFoam. Transition to full transient simulations is considered as indispensable as gateway towards using more detailed turbulence (wall-modeled Large Eddy Simulation WMLES models, boundary layer interaction and influence on the shear force) models;
# * no anisotropy molecular viscosity: although power law could be replaced by more detailed (Oldryd-B model, tensor-based) rheology models;
# * no turbulence models that avoid Reynolds averaging and thus no detailed information on the turbulence field although DES, DDES and LES models are available. Possibly the residence time can be measured experimentally;
# * no model for the residence time of the fluid in  the reactor: although extending the model with passive scalar transport model for a tracer and the inlet/outlet values can be monitored over time;
# * no models breakup of nano-cellose fibers due to shear force: although population balance models are available. See publication by VTT.
# * no (detailed?) comparison with lab-scale set-up using the torque on the rotor (Tomas elaborates on what other quanties could be compared here);
#
# <b>Results obtained in  this paper</b>:
# * how to argue that results are correct?
#
# <b>Structure of Paper</b>: This paper is structured as follows:
#
# ### Section 2: Problem Description
#
# Urgent need to optimize the mechanical process of nano-cellulose in terms on energy requirements. Insights from flow modeling are indispensable.
#
# ### Section 3: Mathematical Model
#
# * two fluids: water (Newtonian, first, simulations with water here intended as a reference) and shear thinning liquid with power law (non-Newtonian, molecular viscosity depends upon shear (or shear rate));
# * inlet pressure conditions (pressure or velocity);
# * rotational speed of the rotor (range of angular velocities);
# * stationary iso-thermal incompressible Reynolds-averaged turbulent flow;
# * six-equations Reynolds stress (LRR model) turbulent closure;
# * rough rotor walls (stator walls remain smooth);
# * rotation of rotor at various angular speeds and thus full 3D simulations;
#
# <img src="./schematic-grinder.png" width=400/>
#
# <div class="alert alert-block alert-success"> Fig-1: Schematic representation of the grinder (insert labels).</div>
#
# <img src="./viscosity-shearrate-nanocellulose.png" width=500/>
#
# <div class="alert alert-block alert-success"> Fig-2: Viscosity vs. shear rate of microfibrilated nano-cellulose. Viscosity-shear rate plot using the Kumar-2016 power law with water indicated as a reference. Shear rate in the gap must be confirmed when we have the model with <100 um gap height. (Using this figure avoids disclosing confidential information.)</div>
#
# ### Section 4: Simulation Approach
#
# <b>Parametric CAD model</b> allowing to change gap clearance available on Github. Remark on extension on the outlet to prevent imposing the outlet boundary conditions to close to the millikng gap. Slip boundaries imposed on the walls of the extension.
#
# <b>Mesh Generation</b>: Sequence of meshes (coarse, intermediate and fine) using cfMesh. Volumetric mesh with local refinement zones. Boundary layer to support boundary resolved model and to meet yPlus = 1 criterium. Remark in on mesh is generated using <i>stichmesh</i>. (In case still applicable) Remark on thin pipe around axis of revolution to be excluded from computational domain to facilitate mesh generation. Slip boundary conditions imposed on the lateral walls of the cylinder.
#
# <b>CFD solve</b>: Solved using segregated pressure, velocity and turbulent quantities implemdented in simpleFoam in OpenFoam version (specify version v2601 (or similar) of OpenFoam.com used here) using RANS with six-equation Reynolds stress tensor LRR model;
#
# ### Section 5: Numerical Results
#
# Show representative results for computed quantities such as e.g. the velocity, strain, stress, turbulent kinetic energy and turbulent dissipation rate. Streamlines at different sections of the gap. Discuss effect of dimensionless parameters such as rotational Reynolds number $Re_{\omega}$, dimensionless flow rate $C_w$ and gap aspect ratio $G$. Discuss the implications of the stream traces on the grinding process: can stream tracer explain phenomena observed in experiments (residual fibers, for instance)? Further discussion in the following three subsections.
#
# #### Case-(1/3): Water as Fluid - Smooth Rotor Surface
#
# The aim of this subsection in two-fold. We first seek to reproduce results in literature in order to gain more confidence in the numerical simulations. We subsequently provide a reference for the shear stress in the gap in case of a fluid with constant viscosity and smooth rotor walls. These results will serve as a reference for the results in the forthcoming two sections.
#
# We thus assume both $Re_{\omega}$ and $C_w$ to be fixed (provide value here). We allow the aspect ratio $G$ to gradually decrease (as occurs in practise in various fibrilation degrees of fibrilation). We introduce the Reynolds number with respect to the gap height as $Re_h = \omega \, h \, \nu$. As in Ref-4, we determine the thickness of the boundary on the rotor and stator at three radial positions in the fibrilation zone (cfr. draft slides OFW Porto). We determine the thickness of the von Karman and Bodewald boundary layer $\delta_K$ and $\delta_B$ as outline in Ref-4 Figure-5 on page-12 and compare with the theoretical result $\delta_K \sim Re_h^{-1/2}$ and $\delta_B \sim Re_h^{-1/2}$ for various values of the height $h$.
#
# <div class="alert alert-block alert-success"> Insert here figures of computed velocity and shear stress in case of high viscosity and low viscisoty. Possibly include plot over entire gap as well as plots over lines crossing the gap at various locations.</div>
#
# #### Case-(2/3): Rough Rotor Surface
#
# Vicinity of the rotor surface more viscous than in the previous scenario. How do results above change with the model parameters of the surface roughness of the rotor?
#
# <div class="alert alert-block alert-success"> Insert here figures of computed velocity and shear stress in case of rotor wall with roughness. </div>
#
# #### Case-(3/3): Shear Thinning Fluid
#
# Large strain in the vicinity of the stator surface due to the no-slip boundary condition imposed. We expect surface roughness
#
# <div class="alert alert-block alert-success"> Insert here figures of computed velocity and shear stress in case of shear thinning viscosity. </div>
#
# ### Section 6: Conclusions
#
# ### References
#
# Add references on CFD (e.g. book by Malalaseekera-Versteeg) and references of mechanical production of nano-cellulose;
#
# 1. Moon, R. J. e.a., Chemical Society Reviews. 40 (7): 3941. doi:10.1039/c0cs00108b. ISSN 0306-0012.
#
# 2. Kowalski, Adam J., An expression for the power consumption of in-line rotor-stator devices, Chemical Engineering and Processing: Process Intensification, 48, (2009), 581–585.
#
# 3. Launder, Poncet and Serre, Laminar, Transitional and Turbulent Flow in Rotating Cavities, Annual Review Fluid Mechanics, 2010;
#
# 4. Hop, Hydrodynamics of a rotor–stator spinning disk reactor: Investigations by large-eddy simulation, Phys. Fluids 35, 2023;
#
# 5. de Beer, Engineering model for single-phase flow in a multi-stage rotor–stator spinning disc reactor, Chemical Engineering Journal, 242, 53–61, 2014.
#
# 6. Park, The Effect of the Rotating Disk Geometry on the Flow and Flux Enhancement in a Dynamic Filtration System, Membranes, 13, 291, 2023.
#
# 7. Kumar, Vinay, Nazari Behzad, Bousfield Douglas, Toivakka Martti. Rheology of Microfibrillated Cellulose
# Suspensions in Pressure-Driven Flow.“ Applied Rheology, 2016;
#
# 8. Kondora, Grzegorz and Asendrych, Dariusz, Flow modelling in a low consistency disc refiner, Nordic Pulp and Paper Research Journal, Vol 28, no 1/2013
#
# ### Acknowledgement
#
# Gratitude of Franjo Juretic for support in using cfMesh.
